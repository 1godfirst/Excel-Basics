# %% [markdown]
# Data Cleaning & Essential Functions
#
# 1. What is the data cleaning, and why is it so important in data analysis?
# What are the potential consequences of analyzing unclean and messy data?
# Explain the common step involved in data cleaning and organizing data.
#
#    -> Data cleaning is the process of correcting errors, inconsistencies,    duplicates, and missing values in a dataset.
#    it is important for ^saving the time in analysis
#    for accurate analysis
#    for improve data quality !
#
#    Potential consequences of analyzing unclean and messy data
#
#     Incorrect conclusions
#     Poor business decisions
#     Inaccurate reports
#     Reduced credibility of analysis
#     Increased errors in calculations
#     Wasted time and resources
#
#     Step involved in data cleaning and organizing data
#     - Sorting
#     - Filtering
#     - removing duplicates
#     - text functions
#     - data validation
#
# 2. How would you sort the following dataset first by "department"(A-Z) and then
# by "Salary"(Largest to the smallest)? Write step by step approach.
#
#     -> First we go in the home tab in editing group in sort&filter we can see an option custom filter click on that first select department in sort, cell values in sort on and order a to z after that we simply click on add level.
#     it will create one more sorting bar, in sort select salary, select cell values in sort on and select sort order largest to smallest click on ok.
#     you data is ready as per the needs.
#
# 3. Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning.
#
#     -> Trim - for removes extra spaces in text or paragraph.
#     - Left - extract letters from left.
#     - Right - extract letters from right.
#     - Mid - extract letters from middle.
#     - Concat - join the text.
#
#
# 4. What is the role of date functions like TODAY in managing datasets?
#
#      -> Key roles of date functions in managing datasets
#      - Dynamics reports : in this whenever workbook will be opened it will change the date.
#      - In calculatin the ages or time period
#      - In tracking the timeline of the task.
#
# 5.
# ![image.png](data:image/png;base64,...)
#
#      ->select the cell below the quantity, First we go in the data tab, in data
#       tab there is data tools, in data tool we click on data validation,
#       in data validation tab in setting, in any value select whole number,
#       in between, in minimum type 1, in maximum type 10 , click on input message write title and write this input message, in error message
#       write title and write this error message.
#
# 6. Understand and apply fundamental text functions like LEFT, RIGHT, MID, and LEN.
# Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
# Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
# Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
# Count the total number of characters in the string "Hello World!" using the LEN function.
# Create a formula to extract the middle 6 characters from "12345-67890-ABCDE".
#
#      -> =Left(ExcelTipsAreGreat,5) or we can select the text cell !
#      - =Right(DataAnalysis.xlsxt,4) or we can select the text cell !
#      - =MID(ExcelTipsAreGreat,6,4) or we can select the text cell !
#      - =LEN(Hello World) or we can select the text cell !
#      - =MID("12345-67890-ABCDE",7,6) or we can select the text cell !
#
# 7. Understand how to combine text using CONCAT, TEXTJOIN, and the & operator.
#  a. Use CONCAT to combine "Hello" and "World" with a space in between.
#
#  b. Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
#
#  c. Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel
# Functions".
#
#  d. Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
#  e. Combine first names in column A with last names in column B to create full names in column C.
#
#      -> a. =CONCAT(Hello," ",World)
#      b. =TEXTJOIN(", ",TRUE,Apple,Banana,Cherry)
#      c. ="2025" & ": " & "Excel Functions"
#      d. =TEXTJOIN(", ",TRUE,A1:A5)
#      e. A2&" "&B2 or =CONCAT(A1," ",B1)
#
#
# 8.
#
# ![image.png](data:image/png;base64,...)
#
#      -> a. TODAY()	Current date
#         NOW()	Current date + time
#         Example
#         TODAY(): Attendance date
#         NOW(): Login timestamp
#
#       b.
#
#
#
#       c. =TEXT(NOW(),"MM/DD/YYYY HH:MM AM/PM")
#
#
#
#
#
#       d. The date automatically updates when the file is reopened.
#
#       e. Ctrl + ;
